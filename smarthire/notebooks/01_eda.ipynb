# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../')
from src.config import DATA_RAW, DATA_INT

# %%
resumes = pd.read_csv(DATA_RAW / 'resumes_clean.csv')
jobs = pd.read_csv(DATA_INT / 'jobs_reduced.csv')

# %%
plt.figure(figsize=(10, 8))
sns.countplot(y='Category', data=resumes, order=resumes['Category'].value_counts().index)
plt.title('Distribution of Resume Categories')
plt.show()

# %%
print("Job Dataset Info:")
print(jobs.info())
# Out:
# Job Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        10000 non-null  str
#  1   company      9893 non-null   str
#  2   location     9959 non-null   str
#  3   skills       1799 non-null   str
#  4   description  9999 non-null   str
#  5   experience   7994 non-null   str
#  6   source       10000 non-null  str
#  7   text         10000 non-null  str
# dtypes: str(8)
# memory usage: 68.0 MB
# None
